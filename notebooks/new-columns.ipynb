# %% [markdown]
# # Generate new columns to map
# * Unsheltered density (unsheltered / sqmi)
# * unsheltered rate per 1000 residents (unsheltered / pop * 1000)
# * Move to script when finished
# * CARE density (encampment calls / sqmi)
# * CARE rate per 1000 residents (encampment calls / pop * 1000)
# * 3-yr average homeless count
# * 3-yr average CARE calls
# * change from prior year

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import intake
import boto3

# %%
catalog = intake.open_catalog('./catalogs/*.yml')
s3 = boto3.client('s3')
bucket_name = 's3://city-of-los-angeles-data-lake/public-health-dashboard/'

# %%
df = gpd.read_file('../gis/homelessness_care_tracts.geojson')

# %% [markdown]
# ## Density and rate per 100

# %%
# Generate new columns for density and rate per 1000 residents
for col in ['unsheltered', 'encampment']:
    density_col = f'{col}_density'
    pct_col = f'pct_{col}'
    df[density_col] = df[col] / df.clipped_area
    df[pct_col] = df[col] / df['pop'] * 1000  

df.head()
# Out:
#          GEOID  SPA  SD  CD  year  unsheltered  sheltered  tot_homeless  \
# 0  06037139301    2   3   3  2017       16.156        0.0        16.156
# 1  06037139301    2   3   3  2018        1.000        0.0         1.000
# 2  06037139301    2   3   3  2019        4.315        0.0         4.315
# 3  06037139302    2   3   3  2017        4.021        0.0         4.021
# 4  06037139302    2   3   3  2018        3.000        0.0         3.000
#
#    bulky  encampment  illegal  other   pop  full_area  clipped_area  \
# 0      1          28        1      0  4603   1.106305      1.106305
# 1      0           5        4      0  4603   1.106305      1.106305
# 2      6          54        0      0  4603   1.106305      1.106305
# 3      0           5        0      0  5389   0.130598      0.130598
# 4      0           2        0      0  5389   0.130598      0.130598
#
#                                             geometry  unsheltered_density  \
# 0  POLYGON ((-118.57150 34.17758, -118.57148 34.1...            14.603564
# 1  POLYGON ((-118.57150 34.17758, -118.57148 34.1...             0.903910
# 2  POLYGON ((-118.57150 34.17758, -118.57148 34.1...             3.900370
# 3  POLYGON ((-118.54073 34.18019, -118.54070 34.1...            30.789116
# 4  POLYGON ((-118.54073 34.18019, -118.54070 34.1...            22.971238
#
#    pct_unsheltered  encampment_density  pct_encampment
# 0         3.509885           25.309470        6.082989
# 1         0.217250            4.519548        1.086248
# 2         0.937432           48.811121       11.731479
# 3         0.746150           38.285396        0.927816
# 4         0.556690           15.314158        0.371126

# %% [markdown]
# ## Change from prior year

# %%
# Change from prior year
tract_characteristics = df[['GEOID']].drop_duplicates()

# %%
unshelt = df[['GEOID', 'year', 'unsheltered']]

# %%
unshelt_wide = unshelt.pivot(index = 'GEOID', columns = 'year', values = 'unsheltered').reset_index()
unshelt_wide.rename(columns = {2017: 'unsheltered2017', 2018: 'unsheltered2018', 
                      2019: 'unsheltered2019'}, inplace = True)

# Add change (absolute count differences between years)
unshelt_wide['change_1718'] = unshelt_wide.unsheltered2018 - unshelt_wide.unsheltered2017
unshelt_wide['change_1819'] = unshelt_wide.unsheltered2019 - unshelt_wide.unsheltered2018


# Merge tract characteristics back in
change_prior = pd.merge(tract_characteristics, unshelt_wide, on = 'GEOID', how = 'left', validate = 'm:1')

# %%
change_prior.head()
# Out:
#          GEOID  unsheltered2017  unsheltered2018  unsheltered2019  \
# 0  06037139301           16.156            1.000            4.315
# 1  06037139302            4.021            3.000           10.448
# 2  06037139502            2.926           15.421            3.119
# 3  06037139600            6.946            2.676           11.488
# 4  06037139701            9.021            1.000            5.119
#
#    change_1718  change_1819
# 0      -15.156        3.315
# 1       -1.021        7.448
# 2       12.495      -12.302
# 3       -4.270        8.812
# 4       -8.021        4.119

# %% [markdown]
# ## 3-year average

# %%
# Average over 3 years
avg = df.groupby('GEOID').agg({'unsheltered': 'mean', 
                     'encampment': 'mean'}).reset_index()
avg.head()
# Out:
#          GEOID  unsheltered  encampment
# 0  06037101110     9.832667    1.000000
# 1  06037101122     1.539333    0.000000
# 2  06037101210    13.965667    1.000000
# 3  06037101220    24.154667    0.333333
# 4  06037101300    12.236667    2.666667

# %% [markdown]
# ## Merge together

# %%
tract_level = pd.merge(change_prior, avg)
tract_level.head()
# Out:
#          GEOID  unsheltered2017  unsheltered2018  unsheltered2019  \
# 0  06037139301           16.156            1.000            4.315
# 1  06037139302            4.021            3.000           10.448
# 2  06037139502            2.926           15.421            3.119
# 3  06037139600            6.946            2.676           11.488
# 4  06037139701            9.021            1.000            5.119
#
#    change_1718  change_1819  unsheltered  encampment
# 0      -15.156        3.315     7.157000   29.000000
# 1       -1.021        7.448     5.823000    6.666667
# 2       12.495      -12.302     7.155333   14.333333
# 3       -4.270        8.812     7.036667   10.333333
# 4       -8.021        4.119     5.046667    2.666667

# %% [markdown]
# * At this point, we have 2 dfs: tract and tract-year
# * Depending on what needs to be mapped, use one of the 2 dfs
# * Should Cleanstat be incorporated?
