# %% [markdown]
# # Identify gaps in CARE service relative to unsheltered population
# * Map number of CARE/CARE+ requests by tract (2017-2019)

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import intake
import ipyleaflet
from ipyleaflet import Map, GeoData, LayersControl, basemaps
import json
from ipywidgets import link, FloatSlider, Text, HTML
from branca.colormap import linear
import boto3

# %%
catalog = intake.open_catalog('../catalogs/*.yml')
bucket_name = 's3://city-of-los-angeles-data-lake/public-health-dashboard/'
s3 = boto3.client('s3')

# %%
df = gpd.read_file(f'{bucket_name}gis/intermediate/homelessness_care_tracts.geojson')
df.rename(columns = {'GEOID': 'id'}, inplace = True)
df = df.set_index('id')
df.head()
# Out:
#              SPA  SD  CD  year  unsheltered  sheltered  tot_homeless  bulky  \
# id
# 06037139301    2   3   3  2017       16.156        0.0        16.156      1
# 06037139301    2   3   3  2018        1.000        0.0         1.000      0
# 06037139301    2   3   3  2019        4.315        0.0         4.315      6
# 06037139302    2   3   3  2017        4.021        0.0         4.021      0
# 06037139302    2   3   3  2018        3.000        0.0         3.000      0
#
#              encampment  illegal  other   pop  full_area  clipped_area  \
# id
# 06037139301          28        1      0  4603   1.106305      1.106305
# 06037139301           5        4      0  4603   1.106305      1.106305
# 06037139301          54        0      0  4603   1.106305      1.106305
# 06037139302           5        0      0  5389   0.130598      0.130598
# 06037139302           2        0      0  5389   0.130598      0.130598
#
#                                                       geometry
# id
# 06037139301  POLYGON ((-118.57150 34.17758, -118.57148 34.1...
# 06037139301  POLYGON ((-118.57150 34.17758, -118.57148 34.1...
# 06037139301  POLYGON ((-118.57150 34.17758, -118.57148 34.1...
# 06037139302  POLYGON ((-118.54073 34.18019, -118.54070 34.1...
# 06037139302  POLYGON ((-118.54073 34.18019, -118.54070 34.1...

# %%
df.groupby('year').agg({'encampment': 'sum'}).reset_index()
# Out:
#    year  encampment
# 0  2017       13953
# 1  2018       21148
# 2  2019       26206

# %% [markdown]
# ## Total CARE Requests

# %%
df1 = df.dissolve(by = ['id', 'clipped_area', 'full_area', 
                        'CD', 'pop', 'SPA', 'SD'], aggfunc = 'sum').reset_index().drop(columns = ['year'])
# to_json converts the gdf to json. json.loads converts it into dictionary 
# geo_data can have many more columns than just geometry. Need to include other columns if you want to have the HTML popup include info.
geo_data = json.loads(df1.set_index('id').to_json())

# Take what we want to map and turn it into a dictionary
# Can only include the key-value pair, the value you want to map, nothing more.
tot_care = dict(zip(df1['id'].tolist(), df1['encampment'].tolist()))

df1.encampment.describe()
# Out:
# count     994.000000
# mean       61.677062
# std       122.258584
# min         0.000000
# 25%         7.000000
# 50%        25.000000
# 75%        67.750000
# max      2351.000000
# Name: encampment, dtype: float64

# %%
m = ipyleaflet.Map(center = (34.0536, -118.2427), zoom = 10,
                  basemap = basemaps.CartoDB.Positron)

layer = ipyleaflet.Choropleth(
    geo_data = geo_data,
    choro_data = tot_care,
    colormap = linear.viridis,
    border_color = 'white',
    style = {'fillOpacity': 0.7, 'weight': 0.8, 'color': 'white', 'opacity': 0.8},
    hover_style = {'fillOpacity': 0.85},
    value_min = 0,
    value_max = 100
)

html = HTML(''' 
    Hover over a tract
''')

html.layout.margin = '0 px 10px 10px 10px'

def update_html(feature, id, **kwargs): 
    html.value = '''
        Census Tract:  
        <b>{}</b> <br>
        Total CARE Requests:
        {} 
    '''.format(id, feature['properties']['encampment'])
 
    
layer.on_hover(update_html)



control = ipyleaflet.WidgetControl(widget = html, position = 'topright')
m.add_layer(layer)
m.add_control(control)

m
# Out:
# Map(basemap={'url': 'http://c.basemaps.cartocdn.com/light_all/{z}/{x}/{y}.png', 'max_zoom': 20, 'attribution':…

# %% [markdown]
# ## CARE Requests per 100 residents

# %%
df2 = df1.copy()
df2['care_per100'] = df2.apply(lambda row: row['encampment'] / row['pop'] * 100 if row['pop'] != 0 else np.nan, axis = 1)

care_per100 = dict(zip(df2['id'].tolist(), df2['care_per100'].tolist()))

df2.care_per100.describe()
# Out:
# count     989.000000
# mean        3.669005
# std        46.814030
# min         0.000000
# 25%         0.172911
# 50%         0.622483
# 75%         1.761543
# max      1420.000000
# Name: care_per100, dtype: float64

# %%
m = ipyleaflet.Map(center = (34.0536, -118.2427), zoom = 10,
                  basemap = basemaps.CartoDB.Positron)

layer = ipyleaflet.Choropleth(
    geo_data = geo_data,
    choro_data = care_per100,
    colormap = linear.viridis,
    border_color = 'white',
    style = {'fillOpacity': 0.7, 'weight': 0.8, 'color': 'white', 'opacity': 0.8},
    hover_style = {'fillOpacity': 0.85}
)

html = HTML(''' 
    Hover over a tract
''')

html.layout.margin = '0 px 10px 10px 10px'

def update_html(feature, id, **kwargs): 
    html.value = '''
        Census Tract:  
        <b>{}</b> <br>
        CARE Requests per 100:
        {} 
    '''.format(id, feature['properties']['care_per100'])
 
    
layer.on_hover(update_html)



control = ipyleaflet.WidgetControl(widget = html, position = 'topright')
m.add_layer(layer)
m.add_control(control)

m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-602e82fb53b8> in <module>
#       8     border_color = 'white',
#       9     style = {'fillOpacity': 0.7, 'weight': 0.8, 'color': 'white', 'opacity': 0.8},
# ---> 10     hover_style = {'fillOpacity': 0.85}
#      11 )
#      12
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in __init__(self, **kwargs)
#     576
#     577     def __init__(self, **kwargs):
# --> 578         super(Choropleth, self).__init__(**kwargs)
#     579         self.data = self._get_data()
#     580
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in __init__(self, **kwargs)
#     496
#     497     def __init__(self, **kwargs):
# --> 498         super(GeoJSON, self).__init__(**kwargs)
#     499         self.on_msg(self._handle_m_msg)
#     500
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in __init__(self, **kwargs)
#      93
#      94     def __init__(self, **kwargs):
# ---> 95         super(Layer, self).__init__(**kwargs)
#      96         self.on_msg(self._handle_mouse_events)
#      97
#
# /opt/conda/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     408         """Public constructor"""
#     409         self._model_id = kwargs.pop('model_id', None)
# --> 410         super(Widget, self).__init__(**kwargs)
#     411
#     412         Widget._call_widget_constructed(self)
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# /opt/conda/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# /opt/conda/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     602                 # Send new state to front-end
#     603                 self.send_state(key=name)
# --> 604         super(Widget, self).notify_change(change)
#     605
#     606     def __repr__(self):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in _update_data(self, change)
#     550     @observe('value_min', 'value_max', 'geo_data', 'choro_data', 'colormap', 'border_color')
#     551     def _update_data(self, change):
# --> 552         self.data = self._get_data()
#     553
#     554     @default('colormap')
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in _get_data(self)
#     561
#     562         if self.value_min is None:
# --> 563             self.value_min = min(self.choro_data.items(), key=lambda x: x[1])[1]
#     564         if self.value_max is None:
#     565             self.value_max = max(self.choro_data.items(), key=lambda x: x[1])[1]
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# /opt/conda/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     602                 # Send new state to front-end
#     603                 self.send_state(key=name)
# --> 604         super(Widget, self).notify_change(change)
#     605
#     606     def __repr__(self):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in _update_data(self, change)
#     550     @observe('value_min', 'value_max', 'geo_data', 'choro_data', 'colormap', 'border_color')
#     551     def _update_data(self, change):
# --> 552         self.data = self._get_data()
#     553
#     554     @default('colormap')
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in _get_data(self)
#     563             self.value_min = min(self.choro_data.items(), key=lambda x: x[1])[1]
#     564         if self.value_max is None:
# --> 565             self.value_max = max(self.choro_data.items(), key=lambda x: x[1])[1]
#     566
#     567         colormap = self.colormap.scale(self.value_min, self.value_max)
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# /opt/conda/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     602                 # Send new state to front-end
#     603                 self.send_state(key=name)
# --> 604         super(Widget, self).notify_change(change)
#     605
#     606     def __repr__(self):
#
# /opt/conda/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in _update_data(self, change)
#     550     @observe('value_min', 'value_max', 'geo_data', 'choro_data', 'colormap', 'border_color')
#     551     def _update_data(self, change):
# --> 552         self.data = self._get_data()
#     553
#     554     @default('colormap')
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in _get_data(self)
#     566
#     567         colormap = self.colormap.scale(self.value_min, self.value_max)
# --> 568         color_dict = {key: colormap(self.choro_data[key]) for key in self.choro_data.keys()}
#     569
#     570         data = copy.deepcopy(self.geo_data)
#
# /opt/conda/lib/python3.7/site-packages/ipyleaflet/leaflet.py in <dictcomp>(.0)
#     566
#     567         colormap = self.colormap.scale(self.value_min, self.value_max)
# --> 568         color_dict = {key: colormap(self.choro_data[key]) for key in self.choro_data.keys()}
#     569
#     570         data = copy.deepcopy(self.geo_data)
#
# /opt/conda/lib/python3.7/site-packages/branca/colormap.py in __call__(self, x)
#     140         form of a string of hewadecimal values "#RRGGBB".
#     141         """
# --> 142         return self.rgb_hex_str(x)
#     143
#     144     def _repr_html_(self):
#
# /opt/conda/lib/python3.7/site-packages/branca/colormap.py in rgb_hex_str(self, x)
#     134         form of a string of hewadecimal values "#RRGGBB".
#     135         """
# --> 136         return '#%02x%02x%02x' % self.rgb_bytes_tuple(x)
#     137
#     138     def __call__(self, x):
#
# /opt/conda/lib/python3.7/site-packages/branca/colormap.py in rgb_bytes_tuple(self, x)
#     128         form of a tuple (R,G,B) with int values between 0 and 255.
#     129         """
# --> 130         return self.rgba_bytes_tuple(x)[:3]
#     131
#     132     def rgb_hex_str(self, x):
#
# /opt/conda/lib/python3.7/site-packages/branca/colormap.py in rgba_bytes_tuple(self, x)
#     122         form of a tuple (R,G,B,A) with int values between 0 and 255.
#     123         """
# --> 124         return tuple(int(u*255.9999) for u in self.rgba_floats_tuple(x))
#     125
#     126     def rgb_bytes_tuple(self, x):
#
# /opt/conda/lib/python3.7/site-packages/branca/colormap.py in rgba_floats_tuple(self, x)
#     213             p = 1.
#     214         else:
# --> 215             raise ValueError('Thresholds are not sorted.')
#     216
#     217         return tuple((1.-p) * self.colors[i-1][j] + p*self.colors[i][j] for j
#
# ValueError: Thresholds are not sorted.
